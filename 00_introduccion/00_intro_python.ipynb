# %% [markdown]
# # Módulo 00 — Introducción a Python
#
# En este módulo revisaremos los fundamentos de Python necesarios para trabajar en el ecosistema científico.
#
# ## Contenido
# - Variables y tipos de datos
# - Estructuras de control (if, for, while)
# - Funciones y módulos
# - Manejo de archivos
# - Introducción a entornos virtuales y Jupyter

# %%
# Tipos de datos básicos
nombre = 'Python Científico'
version = 3.11
es_cientifico = True
print(f'Bienvenido a {nombre} v{version}')
