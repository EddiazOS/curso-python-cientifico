# %% [markdown]
# # Módulo 01 — NumPy: Arreglos Numéricos
#
# NumPy es la base del ecosistema científico en Python.
#
# ## Contenido
# - Creación de arrays
# - Operaciones vectorizadas
# - Indexado y slicing
# - Álgebra lineal básica
# - Estadísticas descriptivas

# %%
import numpy as np

# Crear un array
arr = np.array([1, 2, 3, 4, 5])
print('Array:', arr)
print('Media:', arr.mean())
print('Desviación estándar:', arr.std())
